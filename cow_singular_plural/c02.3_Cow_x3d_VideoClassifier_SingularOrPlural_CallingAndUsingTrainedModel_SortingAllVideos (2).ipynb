# %%
# !pip install pytorchvideo torchvision av
# Out:
# Requirement already satisfied: pytorchvideo in /usr/local/lib/python3.13/dist-packages (0.1.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (0.26.0+cu128)
# Requirement already satisfied: av in /usr/local/lib/python3.13/dist-packages (18.1.0)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.13/dist-packages (from pytorchvideo) (0.1.5.post20221221)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.13/dist-packages (from pytorchvideo) (0.9.0)
# Requirement already satisfied: iopath in /usr/local/lib/python3.13/dist-packages (from pytorchvideo) (0.1.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from pytorchvideo) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.1.3)
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.11.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (4.67.3)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (0.9.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.13/dist-packages (from iopath->pytorchvideo) (4.3.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0->torchvision) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch==2.11.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch==2.11.0->torchvision) (3.0.3)

# %%
# --- 0. THE PYTORCHVIDEO BUG FIX (Monkey Patch) ---
import sys
import torchvision.transforms.functional as F_vision
sys.modules['torchvision.transforms.functional_tensor'] = F_vision

# --- 1. IMPORTS ---
import os
import shutil
import torch
import torch.nn as nn
import torch.nn.functional as F
from google.colab import drive

from torchvision.transforms import Compose, Lambda, Resize
from torchvision.transforms._transforms_video import NormalizeVideo
from pytorchvideo.transforms import ApplyTransformToKey, UniformTemporalSubsample
from pytorchvideo.data.encoded_video import EncodedVideo

# --- 2. CONFIGURATION ---
# Connect to Google Drive
drive.mount('/content/drive', force_remount=True)

CLASSES = ['cow_singular', 'cow_plural']
NUM_FRAMES = 16  # X3D defaults to 16 frames
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- THE MAGIC THRESHOLD ---
# Anything below 55% confidence gets sorted into Miscellaneous
THRESHOLD = 0.55

# The Paths
# Updated to match the X3D model name we saved during training
MODEL_WEIGHTS_PATH = "/content/drive/MyDrive/Trained_Models/c02.2.1_cow_x3d_singular_plural_TrainedModel.pth"
TEST_FOLDER_PATH = "/content/drive/MyDrive/Test/reduced_frame_cow_data_18frames_damaged_videos_removed/Predicted_undamaged_videos"
RESULT_FOLDER_PATH = "/content/drive/MyDrive/Result"

# Mapping the guesses to your folders (Added the Miscellaneous bucket!)
BUCKET_NAMES = {
    'cow_singular': 'Predicted_cow_singular',
    'cow_plural': 'Predicted_cow_plural',
    'miscellaneous': 'Predicted_Miscellaneous'
}

# --- 3. BUILD THE ROBOT BODY & LOAD THE BRAIN ---
print("Building the robot (X3D-M) and loading the brain...")
model = torch.hub.load('facebookresearch/pytorchvideo', 'x3d_m', pretrained=False)

# Change the head so it knows we only have 2 classes
in_features = model.blocks[5].proj.in_features
model.blocks[5].proj = nn.Linear(in_features, len(CLASSES))

model.load_state_dict(torch.load(MODEL_WEIGHTS_PATH, map_location=DEVICE))
model = model.to(DEVICE)
model.eval()

# --- 4. VIDEO GLASSES (TRANSFORMS) ---
video_transform = Compose([
    ApplyTransformToKey(
        key="video",
        transform=Compose([
            UniformTemporalSubsample(NUM_FRAMES),
            Lambda(lambda x: x / 255.0),
            NormalizeVideo(mean=[0.45, 0.45, 0.45], std=[0.225, 0.225, 0.225]), # X3D specifics
            Resize((256, 256)) # X3D specifics
        ])
    )
])

# --- 5. THE SORTING LOOP ---
print(f"\n--- STARTING THE SORTING MACHINE (Threshold: {THRESHOLD*100}%) ---")

# Look at every single file inside the test folder
for filename in os.listdir(TEST_FOLDER_PATH):

    # Only look at video files, ignore random hidden files
    if not filename.lower().endswith(('.mp4', '.avi', '.mov')):
        continue

    video_path = os.path.join(TEST_FOLDER_PATH, filename)
    print(f"\nWatching: {filename}...")

    try:
        # Load the 2-second clip and put the glasses on it
        video = EncodedVideo.from_path(video_path)
        video_data = video.get_clip(start_sec=0.0, end_sec=2.0)
        video_data = video_transform(video_data)
        input_tensor = video_data["video"].unsqueeze(0).to(DEVICE)

        # Make the guess!
        with torch.no_grad():
            output = model(input_tensor)
            probs = F.softmax(output, dim=1)
            conf, pred_idx = torch.max(probs, 1)

        # --- THE MISCELLANEOUS INTERCEPT ---
        confidence_score = conf.item()
        original_guess = CLASSES[pred_idx.item()]

        if confidence_score < THRESHOLD:
            winning_guess = 'miscellaneous'
            print(f"Guess: MISCELLANEOUS (Unsure about {original_guess.upper()}, only {confidence_score*100:.2f}% sure)")
        else:
            winning_guess = original_guess
            print(f"Guess: {winning_guess.upper()} ({confidence_score*100:.2f}% sure)")

        # --- THE FILE MOVING MAGIC ---
        # Look up the exact folder name from your dictionary
        target_bucket = BUCKET_NAMES[winning_guess]

        # Build the paths
        target_folder = os.path.join(RESULT_FOLDER_PATH, target_bucket)
        target_path = os.path.join(target_folder, filename)

        # ⭐️ IMPORTANT: Make sure the folder exists!
        # If 'Predicted_Miscellaneous' isn't in your drive yet, this line creates it automatically.
        os.makedirs(target_folder, exist_ok=True)

        # Copy the video into your folder!
        shutil.copy(video_path, target_path)
        print(f"-> Safely copied into {target_bucket}!")

    except Exception as e:
        print(f"Oh no! Something went wrong with {filename}: {e}")

print("\n--- ALL DONE! CHECK YOUR RESULT FOLDERS! ---")
# Out:
# /usr/local/lib/python3.13/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# Mounted at /content/drive
# Building the robot (X3D-M) and loading the brain...
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# --- STARTING THE SORTING MACHINE (Threshold: 55.00000000000001%) ---
#
# Watching: apr17_t0006_f031072.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f007766.mp4...
# Guess: COW_PLURAL (72.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f018289.mp4...
# Guess: COW_PLURAL (69.27% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f001538.mp4...
# Guess: COW_SINGULAR (71.37% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f026221.mp4...
# Guess: COW_SINGULAR (73.03% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f028224.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f024325.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f001920.mp4...
# Guess: COW_SINGULAR (70.48% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f006422.mp4...
# Guess: COW_SINGULAR (62.24% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f020653.mp4...
# Guess: COW_PLURAL (72.81% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f002336.mp4...
# Guess: COW_SINGULAR (68.36% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f000219.mp4...
# Guess: COW_SINGULAR (68.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f029421.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f015157.mp4...
# Guess: COW_PLURAL (66.79% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f032277.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f029031.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f031441.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f018620.mp4...
# Guess: COW_SINGULAR (56.59% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f004279.mp4...
# Guess: COW_SINGULAR (72.66% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f015344.mp4...
# Guess: COW_PLURAL (72.36% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f004718.mp4...
# Guess: COW_SINGULAR (70.60% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f032685.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f013048.mp4...
# Guess: COW_PLURAL (73.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f024718.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f014772.mp4...
# Guess: COW_SINGULAR (72.83% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f003137.mp4...
# Guess: COW_SINGULAR (72.75% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f001123.mp4...
# Guess: COW_SINGULAR (66.58% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f011835.mp4...
# Guess: COW_PLURAL (68.94% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f026650.mp4...
# Guess: COW_SINGULAR (72.85% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f019041.mp4...
# Guess: COW_PLURAL (72.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f029847.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f013905.mp4...
# Guess: COW_SINGULAR (72.80% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f006594.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f000684.mp4...
# Guess: COW_SINGULAR (71.24% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f027402.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f003531.mp4...
# Guess: COW_SINGULAR (72.45% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f028623.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f021031.mp4...
# Guess: COW_PLURAL (72.67% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f000605.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f016601.mp4...
# Guess: COW_PLURAL (72.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f006945.mp4...
# Guess: COW_PLURAL (72.88% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f012490.mp4...
# Guess: COW_SINGULAR (59.73% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f017440.mp4...
# Guess: COW_SINGULAR (67.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f023473.mp4...
# Guess: COW_SINGULAR (72.73% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f021858.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f006141.mp4...
# Guess: COW_PLURAL (71.82% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f013503.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f020269.mp4...
# Guess: COW_PLURAL (71.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f010409.mp4...
# Guess: COW_PLURAL (72.45% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f017043.mp4...
# Guess: COW_PLURAL (70.64% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f014966.mp4...
# Guess: COW_PLURAL (72.80% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f003353.mp4...
# Guess: COW_PLURAL (69.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f030688.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f006530.mp4...
# Guess: COW_PLURAL (72.54% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f018685.mp4...
# Guess: COW_PLURAL (72.94% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f010828.mp4...
# Guess: COW_PLURAL (73.07% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f009609.mp4...
# Guess: COW_SINGULAR (71.90% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f013690.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f023899.mp4...
# Guess: COW_SINGULAR (72.82% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f027046.mp4...
# Guess: COW_SINGULAR (72.79% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f014547.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f008095.mp4...
# Guess: COW_PLURAL (65.82% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f022239.mp4...
# Guess: COW_PLURAL (72.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f019081.mp4...
# Guess: COW_PLURAL (66.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f008826.mp4...
# Guess: COW_SINGULAR (72.85% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f015785.mp4...
# Guess: COW_PLURAL (67.56% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f008469.mp4...
# Guess: COW_SINGULAR (70.88% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f017872.mp4...
# Guess: COW_PLURAL (72.29% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f022640.mp4...
# Guess: COW_SINGULAR (58.16% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f009995.mp4...
# Guess: COW_PLURAL (61.10% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f025860.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f013296.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f016191.mp4...
# Guess: COW_PLURAL (73.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f007312.mp4...
# Guess: COW_PLURAL (71.80% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f019854.mp4...
# Guess: COW_SINGULAR (72.68% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f009235.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f030270.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f019450.mp4...
# Guess: COW_PLURAL (63.15% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f007722.mp4...
# Guess: COW_PLURAL (72.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f014112.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f024126.mp4...
# Guess: COW_PLURAL (68.53% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f031819.mp4...
# Guess: COW_SINGULAR (71.56% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f026509.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f023710.mp4...
# Guess: COW_PLURAL (72.75% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f001028.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f012936.mp4...
# Guess: COW_PLURAL (55.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f032214.mp4...
# Guess: COW_SINGULAR (66.50% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f002949.mp4...
# Guess: COW_PLURAL (72.31% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f014563.mp4...
# Guess: COW_SINGULAR (72.97% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f025296.mp4...
# Guess: COW_PLURAL (72.49% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f031381.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f029730.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f030920.mp4...
# Guess: COW_SINGULAR (72.88% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f030118.mp4...
# Guess: COW_SINGULAR (71.18% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f028136.mp4...
# Guess: COW_SINGULAR (63.17% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f011270.mp4...
# Guess: COW_PLURAL (73.06% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f001792.mp4...
# Guess: COW_SINGULAR (72.97% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f018052.mp4...
# Guess: COW_SINGULAR (72.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f021340.mp4...
# Guess: COW_SINGULAR (72.68% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f032612.mp4...
# Guess: COW_SINGULAR (73.01% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f025720.mp4...
# Guess: COW_PLURAL (72.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f028971.mp4...
# Guess: COW_SINGULAR (72.43% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f014165.mp4...
# Guess: COW_PLURAL (70.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f023289.mp4...
# Guess: COW_PLURAL (71.66% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f030476.mp4...
# Guess: COW_SINGULAR (65.22% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f022470.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f022889.mp4...
# Guess: COW_PLURAL (72.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f010020.mp4...
# Guess: COW_PLURAL (72.32% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f003787.mp4...
# Guess: COW_PLURAL (72.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f027667.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f029353.mp4...
# Guess: COW_SINGULAR (72.84% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f027272.mp4...
# Guess: COW_SINGULAR (73.06% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f013369.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 54.62% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f011682.mp4...
# Guess: COW_PLURAL (72.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f016125.mp4...
# Guess: COW_PLURAL (72.68% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f004955.mp4...
# Guess: COW_PLURAL (72.57% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f007591.mp4...
# Guess: COW_SINGULAR (71.34% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f005733.mp4...
# Guess: COW_PLURAL (72.86% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f022089.mp4...
# Guess: COW_PLURAL (61.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f015968.mp4...
# Guess: COW_PLURAL (72.11% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f019627.mp4...
# Guess: COW_PLURAL (72.11% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f020471.mp4...
# Guess: COW_PLURAL (72.81% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f016536.mp4...
# Guess: COW_PLURAL (57.11% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f021736.mp4...
# Guess: COW_PLURAL (71.37% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f016927.mp4...
# Guess: COW_SINGULAR (62.16% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f020052.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 52.32% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0006_f001461.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f018901.mp4...
# Guess: COW_PLURAL (64.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f004586.mp4...
# Guess: COW_PLURAL (72.67% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f004172.mp4...
# Guess: COW_PLURAL (72.68% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f028564.mp4...
# Guess: COW_SINGULAR (56.65% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f026101.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f000233.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f002174.mp4...
# Guess: COW_SINGULAR (72.93% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f005362.mp4...
# Guess: COW_PLURAL (66.33% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f010419.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f026871.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f012537.mp4...
# Guess: COW_PLURAL (71.97% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f012134.mp4...
# Guess: COW_PLURAL (72.88% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f007144.mp4...
# Guess: COW_SINGULAR (72.88% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f019356.mp4...
# Guess: COW_PLURAL (72.92% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f024613.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 51.61% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f020577.mp4...
# Guess: COW_PLURAL (72.67% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f003965.mp4...
# Guess: COW_SINGULAR (73.05% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f018978.mp4...
# Guess: COW_PLURAL (72.94% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f016293.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 50.57% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f017052.mp4...
# Guess: COW_PLURAL (72.21% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f025345.mp4...
# Guess: COW_PLURAL (72.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f005956.mp4...
# Guess: COW_SINGULAR (72.86% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f028287.mp4...
# Guess: COW_SINGULAR (72.36% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f013176.mp4...
# Guess: COW_SINGULAR (56.57% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f011223.mp4...
# Guess: COW_PLURAL (73.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f017403.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f024951.mp4...
# Guess: COW_SINGULAR (57.65% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f004712.mp4...
# Guess: COW_SINGULAR (72.99% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f021407.mp4...
# Guess: COW_PLURAL (73.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f004343.mp4...
# Guess: COW_SINGULAR (72.97% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f019789.mp4...
# Guess: COW_SINGULAR (62.30% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f005496.mp4...
# Guess: COW_SINGULAR (72.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f030696.mp4...
# Guess: COW_PLURAL (71.78% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f025792.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f031056.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 54.72% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f002792.mp4...
# Guess: COW_SINGULAR (71.72% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f026595.mp4...
# Guess: COW_SINGULAR (72.92% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f014764.mp4...
# Guess: COW_PLURAL (73.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f023872.mp4...
# Guess: COW_PLURAL (70.38% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f003222.mp4...
# Guess: COW_SINGULAR (72.96% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f008833.mp4...
# Guess: COW_SINGULAR (72.29% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f029112.mp4...
# Guess: COW_PLURAL (72.42% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f031849.mp4...
# Guess: COW_SINGULAR (68.14% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f018571.mp4...
# Guess: COW_PLURAL (58.30% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f000880.mp4...
# Guess: COW_SINGULAR (72.71% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f029534.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 54.50% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f031472.mp4...
# Guess: COW_SINGULAR (71.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f032620.mp4...
# Guess: COW_SINGULAR (60.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f032237.mp4...
# Guess: COW_SINGULAR (63.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f008413.mp4...
# Guess: COW_SINGULAR (71.72% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f000118.mp4...
# Guess: COW_SINGULAR (72.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f023056.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f028704.mp4...
# Guess: COW_PLURAL (72.60% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f010832.mp4...
# Guess: COW_PLURAL (73.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f001261.mp4...
# Guess: COW_SINGULAR (72.92% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f033000.mp4...
# Guess: COW_SINGULAR (72.77% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f006311.mp4...
# Guess: COW_SINGULAR (72.58% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f015532.mp4...
# Guess: COW_PLURAL (69.85% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f000533.mp4...
# Guess: COW_SINGULAR (70.91% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f030334.mp4...
# Guess: COW_PLURAL (67.22% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f029951.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f006765.mp4...
# Guess: COW_SINGULAR (73.01% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f024240.mp4...
# Guess: COW_PLURAL (72.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f016665.mp4...
# Guess: COW_SINGULAR (66.37% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f022632.mp4...
# Guess: COW_PLURAL (72.41% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0005_f009614.mp4...
# Guess: COW_SINGULAR (72.52% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f013756.mp4...
# Guess: COW_SINGULAR (55.98% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f001618.mp4...
# Guess: COW_SINGULAR (72.65% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f005091.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0005_f003581.mp4...
# Guess: COW_SINGULAR (72.96% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f022291.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f026808.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f000786.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f015136.mp4...
# Guess: COW_PLURAL (72.78% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f011995.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f011611.mp4...
# Guess: COW_PLURAL (73.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f029512.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f003185.mp4...
# Guess: COW_SINGULAR (72.81% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f021071.mp4...
# Guess: COW_PLURAL (72.81% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f003572.mp4...
# Guess: COW_SINGULAR (72.98% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f008826.mp4...
# Guess: COW_PLURAL (70.97% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f010413.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f012785.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 54.87% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f021804.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f013940.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f002057.mp4...
# Guess: COW_SINGULAR (71.42% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f028697.mp4...
# Guess: COW_SINGULAR (64.67% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f010788.mp4...
# Guess: COW_PLURAL (72.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f004826.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f027539.mp4...
# Guess: COW_SINGULAR (59.20% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f019512.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f002819.mp4...
# Guess: COW_SINGULAR (69.60% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f023496.mp4...
# Guess: COW_SINGULAR (61.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f019929.mp4...
# Guess: COW_PLURAL (72.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f009975.mp4...
# Guess: COW_SINGULAR (65.19% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f031590.mp4...
# Guess: COW_SINGULAR (72.90% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f001227.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f023072.mp4...
# Guess: COW_PLURAL (56.44% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f026418.mp4...
# Guess: COW_SINGULAR (72.85% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f020177.mp4...
# Guess: COW_PLURAL (72.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f024730.mp4...
# Guess: COW_PLURAL (72.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f015962.mp4...
# Guess: COW_SINGULAR (72.98% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f000405.mp4...
# Guess: COW_SINGULAR (72.34% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f032431.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f006044.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f023957.mp4...
# Guess: COW_PLURAL (59.34% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f001645.mp4...
# Guess: COW_SINGULAR (73.01% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f012419.mp4...
# Guess: COW_PLURAL (72.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f003997.mp4...
# Guess: COW_SINGULAR (72.97% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f005252.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f013555.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f023476.mp4...
# Guess: COW_PLURAL (72.98% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f030321.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f006445.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f025152.mp4...
# Guess: COW_PLURAL (70.57% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f022176.mp4...
# Guess: COW_SINGULAR (69.79% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f006833.mp4...
# Guess: COW_SINGULAR (72.92% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f009598.mp4...
# Guess: COW_SINGULAR (71.27% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f005694.mp4...
# Guess: COW_SINGULAR (73.06% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f029103.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f033218.mp4...
# Guess: COW_SINGULAR (71.05% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f020945.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f009196.mp4...
# Guess: COW_PLURAL (69.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f028306.mp4...
# Guess: COW_PLURAL (66.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f014395.mp4...
# Guess: COW_PLURAL (73.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0004_f004434.mp4...
# Guess: COW_SINGULAR (72.98% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f003473.mp4...
# Guess: COW_SINGULAR (72.83% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f005084.mp4...
# Guess: COW_SINGULAR (67.67% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f000273.mp4...
# Guess: COW_SINGULAR (60.03% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f020349.mp4...
# Guess: COW_PLURAL (72.18% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f031905.mp4...
# Guess: COW_SINGULAR (72.58% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f008258.mp4...
# Guess: COW_PLURAL (72.44% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f017018.mp4...
# Guess: COW_PLURAL (63.48% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f015055.mp4...
# Guess: COW_PLURAL (72.54% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f018241.mp4...
# Guess: COW_PLURAL (70.79% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f027171.mp4...
# Guess: COW_SINGULAR (73.06% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f026007.mp4...
# Guess: COW_SINGULAR (71.48% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f000700.mp4...
# Guess: COW_SINGULAR (72.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f003098.mp4...
# Guess: COW_SINGULAR (72.48% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f005540.mp4...
# Guess: COW_PLURAL (71.73% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f010600.mp4...
# Guess: COW_PLURAL (71.88% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f006279.mp4...
# Guess: COW_SINGULAR (72.93% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f004273.mp4...
# Guess: COW_SINGULAR (72.88% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f020710.mp4...
# Guess: COW_PLURAL (72.56% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f013492.mp4...
# Guess: COW_PLURAL (72.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f015860.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 51.69% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f031500.mp4...
# Guess: COW_SINGULAR (72.30% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f029952.mp4...
# Guess: COW_PLURAL (72.32% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f017793.mp4...
# Guess: COW_SINGULAR (72.70% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f004646.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f027593.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f005910.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f032797.mp4...
# Guess: COW_SINGULAR (72.66% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f030737.mp4...
# Guess: COW_SINGULAR (72.90% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f017414.mp4...
# Guess: COW_PLURAL (60.39% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f007819.mp4...
# Guess: COW_SINGULAR (72.56% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f027929.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f009065.mp4...
# Guess: COW_PLURAL (68.42% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f031158.mp4...
# Guess: COW_SINGULAR (72.96% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f030721.mp4...
# Guess: COW_SINGULAR (72.95% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f013117.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f010222.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f032297.mp4...
# Guess: COW_SINGULAR (72.21% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0004_f002429.mp4...
# Guess: COW_SINGULAR (72.40% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f007436.mp4...
# Guess: COW_SINGULAR (70.31% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f031992.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f008645.mp4...
# Guess: COW_PLURAL (71.76% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f014292.mp4...
# Guess: COW_PLURAL (68.62% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f021883.mp4...
# Guess: COW_PLURAL (73.06% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f016229.mp4...
# Guess: COW_SINGULAR (71.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f021487.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f025586.mp4...
# Guess: COW_PLURAL (61.12% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f009814.mp4...
# Guess: COW_PLURAL (72.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f001090.mp4...
# Guess: COW_SINGULAR (72.72% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f018658.mp4...
# Guess: COW_SINGULAR (71.88% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f031153.mp4...
# Guess: COW_SINGULAR (72.26% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f022690.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f009448.mp4...
# Guess: COW_PLURAL (72.71% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f016648.mp4...
# Guess: COW_SINGULAR (68.16% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f002703.mp4...
# Guess: COW_SINGULAR (72.86% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f025557.mp4...
# Guess: COW_SINGULAR (71.63% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f013877.mp4...
# Guess: COW_PLURAL (61.22% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f024362.mp4...
# Guess: COW_SINGULAR (69.56% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0003_f019071.mp4...
# Guess: COW_PLURAL (60.98% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f028728.mp4...
# Guess: COW_PLURAL (64.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f011725.mp4...
# Guess: COW_PLURAL (72.84% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f032665.mp4...
# Guess: COW_SINGULAR (72.29% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f024384.mp4...
# Guess: COW_PLURAL (58.68% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f020733.mp4...
# Guess: COW_PLURAL (63.06% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f012543.mp4...
# Guess: COW_PLURAL (66.83% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f025970.mp4...
# Guess: COW_PLURAL (69.60% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f024014.mp4...
# Guess: COW_PLURAL (59.69% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f013776.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f016269.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 54.99% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f027950.mp4...
# Guess: COW_SINGULAR (72.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f019119.mp4...
# Guess: COW_PLURAL (65.21% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f015019.mp4...
# Guess: COW_PLURAL (60.49% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f016639.mp4...
# Guess: COW_PLURAL (66.59% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f021545.mp4...
# Guess: COW_PLURAL (73.07% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f022391.mp4...
# Guess: COW_PLURAL (72.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f004822.mp4...
# Guess: COW_SINGULAR (67.85% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f020333.mp4...
# Guess: COW_PLURAL (65.79% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f009991.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f015838.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 51.14% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f014673.mp4...
# Guess: COW_PLURAL (72.82% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f018750.mp4...
# Guess: COW_SINGULAR (70.61% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f027173.mp4...
# Guess: COW_SINGULAR (72.79% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f017469.mp4...
# Guess: COW_PLURAL (72.45% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f001501.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f006002.mp4...
# Guess: COW_SINGULAR (65.41% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f023150.mp4...
# Guess: COW_SINGULAR (64.03% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f014624.mp4...
# Guess: COW_PLURAL (72.91% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f010815.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f024774.mp4...
# Guess: COW_PLURAL (72.30% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f013001.mp4...
# Guess: COW_PLURAL (70.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f028330.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 52.44% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f002261.mp4...
# Guess: COW_SINGULAR (72.87% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f026378.mp4...
# Guess: COW_SINGULAR (72.99% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f025172.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f010403.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f015438.mp4...
# Guess: COW_PLURAL (72.94% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0003_f003840.mp4...
# Guess: COW_SINGULAR (72.57% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f018310.mp4...
# Guess: COW_PLURAL (72.77% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f019944.mp4...
# Guess: COW_SINGULAR (62.58% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f023531.mp4...
# Guess: COW_PLURAL (73.07% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f019510.mp4...
# Guess: COW_PLURAL (68.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f033063.mp4...
# Guess: COW_SINGULAR (71.81% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f012140.mp4...
# Guess: COW_PLURAL (73.07% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f017060.mp4...
# Guess: COW_PLURAL (70.98% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f014208.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f029521.mp4...
# Guess: COW_SINGULAR (72.13% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f029119.mp4...
# Guess: COW_SINGULAR (72.74% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f026779.mp4...
# Guess: COW_SINGULAR (72.60% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f006406.mp4...
# Guess: COW_SINGULAR (70.68% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f021950.mp4...
# Guess: COW_SINGULAR (72.86% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f011259.mp4...
# Guess: COW_PLURAL (64.16% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f022767.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 51.57% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f021158.mp4...
# Guess: COW_PLURAL (72.60% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f030312.mp4...
# Guess: COW_SINGULAR (72.69% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f017864.mp4...
# Guess: COW_PLURAL (55.31% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f008782.mp4...
# Guess: COW_PLURAL (72.95% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f029911.mp4...
# Guess: COW_SINGULAR (72.45% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f022057.mp4...
# Guess: COW_PLURAL (72.73% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f000566.mp4...
# Guess: COW_SINGULAR (72.69% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f004406.mp4...
# Guess: COW_SINGULAR (72.03% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f023655.mp4...
# Guess: COW_PLURAL (65.91% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f003289.mp4...
# Guess: COW_SINGULAR (72.79% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f032692.mp4...
# Guess: COW_SINGULAR (73.05% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f016759.mp4...
# Guess: COW_PLURAL (72.10% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f009194.mp4...
# Guess: COW_PLURAL (73.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f005596.mp4...
# Guess: COW_SINGULAR (69.69% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f026037.mp4...
# Guess: COW_PLURAL (70.91% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f020451.mp4...
# Guess: COW_PLURAL (67.19% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f021265.mp4...
# Guess: COW_PLURAL (70.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f019173.mp4...
# Guess: COW_PLURAL (66.60% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f018738.mp4...
# Guess: COW_PLURAL (72.22% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f006778.mp4...
# Guess: COW_SINGULAR (67.45% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f026840.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 53.39% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0001_f028427.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f002450.mp4...
# Guess: COW_SINGULAR (62.64% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f002064.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 54.91% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0001_f020853.mp4...
# Guess: COW_SINGULAR (69.98% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f005219.mp4...
# Guess: COW_SINGULAR (71.40% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f024839.mp4...
# Guess: COW_PLURAL (57.74% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f030323.mp4...
# Guess: COW_SINGULAR (73.05% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f028780.mp4...
# Guess: COW_SINGULAR (71.92% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f025234.mp4...
# Guess: COW_PLURAL (72.95% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f001331.mp4...
# Guess: COW_SINGULAR (72.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0001_f022832.mp4...
# Guess: COW_PLURAL (71.18% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f004033.mp4...
# Guess: COW_SINGULAR (72.78% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f009579.mp4...
# Guess: COW_PLURAL (72.92% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0001_f020060.mp4...
# Guess: COW_PLURAL (72.74% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0002_f000217.mp4...
# Guess: COW_SINGULAR (67.93% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f003639.mp4...
# Guess: COW_SINGULAR (72.64% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0002_f007126.mp4...
# Guess: COW_PLURAL (72.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# ...
#
# Watching: apr17_t0009_f008609.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f026133.mp4...
# Guess: COW_SINGULAR (72.75% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f003289.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f029269.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f008202.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f012541.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f028891.mp4...
# Guess: COW_PLURAL (68.35% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f009468.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f020648.mp4...
# Guess: COW_PLURAL (72.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f025785.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f010968.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f005797.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f030098.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f024943.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f030827.mp4...
# Guess: COW_SINGULAR (72.82% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f027752.mp4...
# Guess: COW_PLURAL (71.67% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f027327.mp4...
# Guess: COW_PLURAL (61.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f017302.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f003673.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f006228.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f004096.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f013363.mp4...
# Guess: COW_SINGULAR (73.05% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f028126.mp4...
# Guess: COW_PLURAL (72.97% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f030449.mp4...
# Guess: COW_SINGULAR (72.99% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f013742.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f019861.mp4...
# Guess: COW_PLURAL (71.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f014140.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f002891.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f017113.mp4...
# Guess: COW_SINGULAR (72.34% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f032439.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f009072.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f016919.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f026517.mp4...
# Guess: COW_SINGULAR (64.97% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f011751.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f031219.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 53.94% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0008_f022958.mp4...
# Guess: COW_PLURAL (71.04% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f000005.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f007048.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f000429.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f029678.mp4...
# Guess: COW_PLURAL (69.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f011144.mp4...
# Guess: COW_PLURAL (73.06% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f018307.mp4...
# Guess: COW_PLURAL (72.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f016269.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 51.43% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0008_f016712.mp4...
# Guess: COW_SINGULAR (72.91% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f021397.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f011549.mp4...
# Guess: COW_PLURAL (72.84% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f031583.mp4...
# Guess: COW_PLURAL (72.93% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f027249.mp4...
# Guess: COW_SINGULAR (73.00% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f032043.mp4...
# Guess: COW_SINGULAR (72.86% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f007803.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f004539.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f013139.mp4...
# Guess: COW_PLURAL (72.49% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f010037.mp4...
# Guess: COW_SINGULAR (58.75% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f021814.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f024146.mp4...
# Guess: COW_PLURAL (71.19% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f011922.mp4...
# Guess: COW_PLURAL (55.99% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f002308.mp4...
# Guess: COW_PLURAL (71.42% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f001200.mp4...
# Guess: COW_SINGULAR (66.99% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f031631.mp4...
# Guess: COW_SINGULAR (68.78% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f004990.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f012737.mp4...
# Guess: COW_SINGULAR (72.58% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f013534.mp4...
# Guess: COW_PLURAL (64.47% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f015885.mp4...
# Guess: COW_SINGULAR (70.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f010561.mp4...
# Guess: COW_SINGULAR (73.08% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f023355.mp4...
# Guess: COW_PLURAL (69.63% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f023711.mp4...
# Guess: COW_PLURAL (71.96% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f029245.mp4...
# Guess: COW_PLURAL (72.76% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f020257.mp4...
# Guess: COW_PLURAL (72.71% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f012324.mp4...
# Guess: COW_SINGULAR (72.18% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f001091.mp4...
# Guess: COW_PLURAL (72.53% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f021068.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f014711.mp4...
# Guess: COW_SINGULAR (72.78% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f002078.mp4...
# Guess: COW_SINGULAR (58.62% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f022222.mp4...
# Guess: COW_PLURAL (73.09% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f028493.mp4...
# Guess: COW_PLURAL (72.54% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f022608.mp4...
# Guess: COW_PLURAL (72.98% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f032834.mp4...
# Guess: COW_SINGULAR (73.06% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0009_f011363.mp4...
# Guess: COW_SINGULAR (73.07% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f010409.mp4...
# Guess: COW_PLURAL (71.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f010592.mp4...
# Guess: COW_PLURAL (72.21% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f023583.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f024806.mp4...
# Guess: COW_SINGULAR (73.01% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f011372.mp4...
# Guess: COW_PLURAL (62.98% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f001905.mp4...
# Guess: COW_PLURAL (69.29% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f019871.mp4...
# Guess: COW_PLURAL (72.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f028876.mp4...
# Guess: COW_PLURAL (72.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f020313.mp4...
# Guess: COW_SINGULAR (72.76% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f032367.mp4...
# Guess: COW_PLURAL (72.95% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f025206.mp4...
# Guess: COW_SINGULAR (61.06% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f031982.mp4...
# Guess: COW_PLURAL (72.79% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f012138.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f023972.mp4...
# Guess: COW_PLURAL (72.81% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f003124.mp4...
# Guess: COW_SINGULAR (72.94% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f000687.mp4...
# Guess: COW_PLURAL (72.18% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f014355.mp4...
# Guess: COW_SINGULAR (72.49% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f030007.mp4...
# Guess: COW_PLURAL (72.89% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f024388.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_SINGULAR, only 50.83% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0007_f005511.mp4...
# Guess: COW_SINGULAR (72.59% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f018258.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f029598.mp4...
# Guess: COW_PLURAL (73.02% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f021911.mp4...
# Guess: COW_SINGULAR (71.56% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f026848.mp4...
# Guess: COW_SINGULAR (72.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0008_f014316.mp4...
# Guess: COW_PLURAL (72.90% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f005113.mp4...
# Guess: COW_SINGULAR (72.75% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f031235.mp4...
# Guess: COW_PLURAL (73.03% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f033149.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f010775.mp4...
# Guess: COW_PLURAL (73.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f001491.mp4...
# Guess: COW_PLURAL (71.25% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0009_f005384.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f032788.mp4...
# Guess: COW_PLURAL (72.91% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f015548.mp4...
# Guess: COW_SINGULAR (67.99% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f028472.mp4...
# Guess: COW_PLURAL (72.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f030427.mp4...
# Guess: COW_PLURAL (73.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f002717.mp4...
# Guess: COW_SINGULAR (72.59% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f028056.mp4...
# Guess: COW_PLURAL (72.97% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f022756.mp4...
# Guess: COW_PLURAL (73.05% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f017929.mp4...
# Guess: COW_PLURAL (64.47% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f023183.mp4...
# Guess: COW_PLURAL (73.08% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f030826.mp4...
# Guess: COW_PLURAL (73.00% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0008_f019463.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_PLURAL, only 54.37% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0007_f022341.mp4...
# Guess: COW_PLURAL (72.48% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f002736.mp4...
# Guess: COW_SINGULAR (72.89% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f031861.mp4...
# Guess: COW_SINGULAR (73.09% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f021482.mp4...
# Guess: COW_PLURAL (73.07% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f020702.mp4...
# Guess: COW_SINGULAR (65.61% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f027807.mp4...
# Guess: COW_SINGULAR (73.04% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f025674.mp4...
# Guess: COW_SINGULAR (73.02% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f033094.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f021082.mp4...
# Guess: COW_SINGULAR (70.13% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f003926.mp4...
# Guess: COW_SINGULAR (64.52% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f023013.mp4...
# Guess: COW_SINGULAR (65.40% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0006_f025476.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f027650.mp4...
# Guess: COW_PLURAL (72.87% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0007_f007394.mp4...
# Guess: COW_PLURAL (73.01% sure)
# -> Safely copied into Predicted_cow_plural!
#
# Watching: apr17_t0006_f025101.mp4...
# Guess: COW_SINGULAR (73.10% sure)
# -> Safely copied into Predicted_cow_singular!
#
# Watching: apr17_t0007_f021492.mp4...
# Guess: COW_SINGULAR (70.44% sure)
# -> Safely copied into Predicted_cow_singular!
#
# --- ALL DONE! CHECK YOUR RESULT FOLDERS! ---
