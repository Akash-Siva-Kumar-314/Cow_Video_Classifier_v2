# %%
# !pip install pytorchvideo torchvision av
# Out:
# Collecting pytorchvideo
#   Downloading pytorchvideo-0.1.5.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (0.26.0+cu128)
# Collecting av
#   Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting fvcore (from pytorchvideo)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting parameterized (from pytorchvideo)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from pytorchvideo)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from pytorchvideo) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.1.3)
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.11.0+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch==2.11.0->torchvision) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->torchvision) (12.8.90)
# Collecting yacs>=0.1.6 (from fvcore->pytorchvideo)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (4.67.3)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from fvcore->pytorchvideo) (0.9.0)
# Collecting portalocker (from iopath->pytorchvideo)
#   Downloading portalocker-4.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0->torchvision) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch==2.11.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch==2.11.0->torchvision) (3.0.3)
# Downloading av-18.1.0-cp311-abi3-manylinux_2_28_x86_64.whl (35.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 27.4 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-4.3.2-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 5.7 MB/s eta 0:00:00
# Building wheels for collected packages: pytorchvideo, fvcore, iopath
#   Building wheel for pytorchvideo (setup.py) ... done
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188757 sha256=26e178db5392a7a49807b270cad55c5da3085a8e976b544450848aecd65ca61b
#   Stored in directory: /root/.cache/pip/wheels/37/56/51/f27c4eb4bcee969fb4577a5b7d90f9cfe596ebd0e4def65ba5
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61447 sha256=fb5ca5239f83ae66232f5acb4b1c14d31f15c97222c5a5a865ea368b06ff73b5
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/9a/9f4843148961a522f56dbeaa5543071ac2389d9a079ec724ab
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31596 sha256=da3183ce81a3aa8ea5c3ea608448cfc40f297d0dc219ddf8513556c38b196124
#   Stored in directory: /root/.cache/pip/wheels/cd/c4/19/776124f304c8d9cb940cb164ec2ad635b42d9d1cf03217506d
# Successfully built pytorchvideo fvcore iopath
# Installing collected packages: yacs, portalocker, parameterized, av, iopath, fvcore, pytorchvideo
# Successfully installed av-18.1.0 fvcore-0.1.5.post20221221 iopath-0.1.10 parameterized-0.9.0 portalocker-4.3.2 pytorchvideo-0.1.5 yacs-0.1.8

# %%
# --- 0. THE PYTORCHVIDEO BUG FIX (Monkey Patch) ---
import sys
import torchvision.transforms.functional as F_vision
sys.modules['torchvision.transforms.functional_tensor'] = F_vision

# --- 1. IMPORTS ---
import os
import shutil
import torch
import torch.nn as nn
import torch.nn.functional as F
from google.colab import drive

from torchvision.transforms import Compose, Lambda, Resize
from torchvision.transforms._transforms_video import NormalizeVideo
from pytorchvideo.transforms import ApplyTransformToKey, UniformTemporalSubsample
from pytorchvideo.data.encoded_video import EncodedVideo

# --- 2. CONFIGURATION ---
# Connect to Google Drive
drive.mount('/content/drive', force_remount=True)

# UPDATED: We now have 3 action classes!
CLASSES = ['cow_eat', 'cow_rest', 'cow_walk_stand']
NUM_FRAMES = 16  # X3D defaults to 16 frames
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- THE MAGIC THRESHOLD ---
# Anything below 50% confidence gets sorted into Miscellaneous
THRESHOLD = 0.50

# --- THE PATHS ---
# UPDATED: Pointing to the new action model and the singular cow test folder
MODEL_WEIGHTS_PATH = "/content/drive/MyDrive/Trained_Models/c03.1.1_cow_x3d_singular_activities_eat_rest_walk_TrainedModel.pth"
TEST_FOLDER_PATH = "/content/drive/MyDrive/Test/Predicted_cow_singular"
RESULT_FOLDER_PATH = "/content/drive/MyDrive/Result"

# UPDATED: Mapping the new guesses to your new folders
BUCKET_NAMES = {
    'cow_eat': 'Predicted_cow_eat',
    'cow_rest': 'Predicted_cow_rest',
    'cow_walk_stand': 'Predicted_cow_walk_stand',
    'miscellaneous': 'Predicted_Miscellaneous'
}

# --- 3. BUILD THE ROBOT BODY & LOAD THE BRAIN ---
print("Building the robot (X3D-M) and loading the brain...")
model = torch.hub.load('facebookresearch/pytorchvideo', 'x3d_m', pretrained=False)

# Change the head so it knows we have 3 classes now
in_features = model.blocks[5].proj.in_features
model.blocks[5].proj = nn.Linear(in_features, len(CLASSES))

model.load_state_dict(torch.load(MODEL_WEIGHTS_PATH, map_location=DEVICE))
model = model.to(DEVICE)
model.eval()

# --- 4. VIDEO GLASSES (TRANSFORMS) ---
video_transform = Compose([
    ApplyTransformToKey(
        key="video",
        transform=Compose([
            UniformTemporalSubsample(NUM_FRAMES),
            Lambda(lambda x: x / 255.0),
            NormalizeVideo(mean=[0.45, 0.45, 0.45], std=[0.225, 0.225, 0.225]), # X3D specifics
            Resize((256, 256)) # X3D specifics
        ])
    )
])

# --- 5. THE SORTING LOOP ---
print(f"\n--- STARTING THE SORTING MACHINE (Threshold: {THRESHOLD*100}%) ---")

# Look at every single file inside the test folder
for filename in os.listdir(TEST_FOLDER_PATH):

    # Only look at video files, ignore random hidden files
    if not filename.lower().endswith(('.mp4', '.avi', '.mov')):
        continue

    video_path = os.path.join(TEST_FOLDER_PATH, filename)
    print(f"\nWatching: {filename}...")

    try:
        # Load the 2-second clip and put the glasses on it
        video = EncodedVideo.from_path(video_path)
        video_data = video.get_clip(start_sec=0.0, end_sec=2.0)
        video_data = video_transform(video_data)
        input_tensor = video_data["video"].unsqueeze(0).to(DEVICE)

        # Make the guess!
        with torch.no_grad():
            output = model(input_tensor)
            probs = F.softmax(output, dim=1)
            conf, pred_idx = torch.max(probs, 1)

        # --- THE MISCELLANEOUS INTERCEPT ---
        confidence_score = conf.item()
        original_guess = CLASSES[pred_idx.item()]

        if confidence_score < THRESHOLD:
            winning_guess = 'miscellaneous'
            print(f"Guess: MISCELLANEOUS (Unsure about {original_guess.upper()}, only {confidence_score*100:.2f}% sure)")
        else:
            winning_guess = original_guess
            print(f"Guess: {winning_guess.upper()} ({confidence_score*100:.2f}% sure)")

        # --- THE FILE MOVING MAGIC ---
        # Look up the exact folder name from your dictionary
        target_bucket = BUCKET_NAMES[winning_guess]

        # Build the paths
        target_folder = os.path.join(RESULT_FOLDER_PATH, target_bucket)
        target_path = os.path.join(target_folder, filename)

        # ⭐️ IMPORTANT: Make sure the folder exists!
        # This will automatically generate the 4 specific folders inside "Result" if they don't exist yet
        os.makedirs(target_folder, exist_ok=True)

        # Copy the video into your folder!
        shutil.copy(video_path, target_path)
        print(f"-> Safely copied into {target_bucket}!")

    except Exception as e:
        print(f"Oh no! Something went wrong with {filename}: {e}")

print("\n--- ALL DONE! CHECK YOUR RESULT FOLDERS! ---")
# Out:
# /usr/local/lib/python3.13/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# Mounted at /content/drive
# Building the robot (X3D-M) and loading the brain...
# Downloading: "https://github.com/facebookresearch/pytorchvideo/zipball/main" to /root/.cache/torch/hub/main.zip
#
# --- STARTING THE SORTING MACHINE (Threshold: 50.0%) ---
#
# Watching: apr17_t0006_f031072.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f001538.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f026221.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f028224.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f024325.mp4...
# Guess: COW_WALK_STAND (57.01% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0007_f001920.mp4...
# Guess: COW_REST (57.24% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f006422.mp4...
# Guess: COW_REST (56.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f002336.mp4...
# Guess: COW_REST (56.25% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f000219.mp4...
# Guess: COW_REST (56.81% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f029421.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f032277.mp4...
# Guess: COW_REST (57.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f029031.mp4...
# Guess: COW_REST (57.56% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f031441.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f018620.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f004279.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f004718.mp4...
# Guess: COW_EAT (57.26% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f032685.mp4...
# Guess: COW_REST (57.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f024718.mp4...
# Guess: COW_WALK_STAND (57.34% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0007_f014772.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f003137.mp4...
# Guess: COW_EAT (55.39% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f001123.mp4...
# Guess: COW_REST (56.83% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f026650.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f029847.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f013905.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f006594.mp4...
# Guess: COW_REST (57.44% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f000684.mp4...
# Guess: COW_REST (57.14% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f027402.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f003531.mp4...
# Guess: COW_EAT (57.27% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f028623.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f000605.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f012490.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 36.86% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0006_f017440.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 48.10% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0006_f023473.mp4...
# Guess: COW_REST (56.74% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f030688.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f009609.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f023899.mp4...
# Guess: COW_WALK_STAND (52.77% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0006_f027046.mp4...
# Guess: COW_REST (57.42% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f008826.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f008469.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f022640.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f025860.mp4...
# Guess: COW_REST (57.36% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f019854.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 38.05% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0006_f009235.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f030270.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f031819.mp4...
# Guess: COW_EAT (57.56% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f026509.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f001028.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f032214.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f014563.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 42.23% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f031381.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f029730.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f030920.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f030118.mp4...
# Guess: COW_EAT (57.31% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f028136.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f001792.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f018052.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f021340.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f032612.mp4...
# Guess: COW_EAT (57.51% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f028971.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 49.26% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f030476.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f027667.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 43.81% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f029353.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 46.94% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0005_f027272.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f007591.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f016927.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f001461.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f028564.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f026101.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f000233.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f002174.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f026871.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f007144.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f003965.mp4...
# Guess: COW_REST (56.14% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f005956.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f028287.mp4...
# Guess: COW_EAT (50.12% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f013176.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f024951.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f004712.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f004343.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f019789.mp4...
# Guess: COW_EAT (57.47% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f005496.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f002792.mp4...
# Guess: COW_REST (55.19% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f026595.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f003222.mp4...
# Guess: COW_REST (57.09% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f008833.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f031849.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f000880.mp4...
# Guess: COW_REST (56.77% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f031472.mp4...
# Guess: COW_EAT (57.20% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f032620.mp4...
# Guess: COW_EAT (57.47% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f032237.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f008413.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f000118.mp4...
# Guess: COW_REST (55.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f001261.mp4...
# Guess: COW_REST (56.96% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f033000.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f006311.mp4...
# Guess: COW_REST (57.42% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f000533.mp4...
# Guess: COW_REST (55.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f006765.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f016665.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f009614.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f013756.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0005_f001618.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f005091.mp4...
# Guess: COW_REST (57.59% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0005_f003581.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f026808.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f000786.mp4...
# Guess: COW_REST (57.46% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f029512.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f003185.mp4...
# Guess: COW_REST (57.39% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f003572.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f002057.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f028697.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f004826.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f027539.mp4...
# Guess: COW_EAT (57.49% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f002819.mp4...
# Guess: COW_REST (57.22% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f023496.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f009975.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f031590.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f001227.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f026418.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f015962.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f000405.mp4...
# Guess: COW_REST (57.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f032431.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f006044.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f001645.mp4...
# Guess: COW_REST (57.60% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f003997.mp4...
# Guess: COW_REST (57.15% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f005252.mp4...
# Guess: COW_REST (57.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f030321.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f006445.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f022176.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f006833.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0004_f009598.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0004_f005694.mp4...
# Guess: COW_REST (57.18% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f029103.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f033218.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 49.29% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f004434.mp4...
# Guess: COW_REST (57.08% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f003473.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f005084.mp4...
# Guess: COW_EAT (57.10% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f000273.mp4...
# Guess: COW_REST (55.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f031905.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 41.08% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f027171.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f026007.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f000700.mp4...
# Guess: COW_REST (56.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f003098.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f006279.mp4...
# Guess: COW_EAT (57.36% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f004273.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f031500.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 42.70% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f017793.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f004646.mp4...
# Guess: COW_EAT (57.47% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f027593.mp4...
# Guess: COW_REST (50.70% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f005910.mp4...
# Guess: COW_EAT (57.36% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f032797.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f030737.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 48.57% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f007819.mp4...
# Guess: COW_EAT (57.36% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f027929.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f031158.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f030721.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f032297.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 43.71% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0004_f002429.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f007436.mp4...
# Guess: COW_EAT (57.53% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f031992.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f016229.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f001090.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 43.65% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f018658.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f031153.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 40.55% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f016648.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f002703.mp4...
# Guess: COW_EAT (56.34% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f025557.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 44.80% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0003_f024362.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f032665.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 40.66% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f027950.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 45.44% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f004822.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f018750.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f027173.mp4...
# Guess: COW_REST (52.26% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f001501.mp4...
# Guess: COW_REST (56.80% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f006002.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 44.89% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f023150.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0003_f002261.mp4...
# Guess: COW_EAT (56.88% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f026378.mp4...
# Guess: COW_REST (51.97% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0003_f003840.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f019944.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f033063.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 41.74% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f029521.mp4...
# Guess: COW_REST (51.33% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f029119.mp4...
# Guess: COW_WALK_STAND (56.49% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0002_f026779.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 41.44% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f006406.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 47.87% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f021950.mp4...
# Guess: COW_EAT (56.23% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f030312.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 43.20% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f029911.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 44.65% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f000566.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f004406.mp4...
# Guess: COW_REST (57.41% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f003289.mp4...
# Guess: COW_REST (57.32% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f032692.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f005596.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f006778.mp4...
# Guess: COW_EAT (52.16% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f002450.mp4...
# Guess: COW_REST (57.34% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f020853.mp4...
# Guess: COW_EAT (55.70% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0002_f005219.mp4...
# Guess: COW_EAT (57.46% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0001_f030323.mp4...
# Guess: COW_REST (55.86% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f028780.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 38.09% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0002_f001331.mp4...
# Guess: COW_REST (57.41% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f004033.mp4...
# Guess: COW_REST (57.24% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f000217.mp4...
# Guess: COW_REST (56.40% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f003639.mp4...
# Guess: COW_REST (57.11% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f029913.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 47.87% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0001_f029136.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0001_f031516.mp4...
# Guess: COW_REST (56.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f030684.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f001694.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f033088.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f031894.mp4...
# Guess: COW_REST (56.79% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f000902.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0002_f002853.mp4...
# Guess: COW_REST (56.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f031122.mp4...
# Guess: COW_REST (56.60% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f002133.mp4...
# Guess: COW_REST (55.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f001351.mp4...
# Guess: COW_REST (56.80% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f000185.mp4...
# Guess: COW_REST (54.46% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f031068.mp4...
# Guess: COW_REST (57.59% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f000981.mp4...
# Guess: COW_REST (55.41% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f032211.mp4...
# Guess: COW_REST (57.46% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f001768.mp4...
# Guess: COW_REST (55.79% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f030323.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f028312.mp4...
# Guess: COW_REST (57.46% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f005356.mp4...
# Guess: COW_REST (55.21% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f004518.mp4...
# Guess: COW_REST (56.03% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f025397.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f003708.mp4...
# Guess: COW_REST (56.22% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f002916.mp4...
# Guess: COW_REST (56.21% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f005706.mp4...
# Guess: COW_REST (56.64% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f032317.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f004067.mp4...
# Guess: COW_REST (55.38% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f000548.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 48.43% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0001_f004958.mp4...
# Guess: COW_REST (57.31% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f003330.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 46.36% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0000_f027459.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f013192.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 45.02% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0000_f022146.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f029146.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f022910.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f033024.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f016721.mp4...
# Guess: COW_REST (56.72% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f020540.mp4...
# Guess: COW_REST (57.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f027691.mp4...
# Guess: COW_WALK_STAND (57.57% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0000_f026220.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f007797.mp4...
# Guess: COW_EAT (55.85% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0000_f024555.mp4...
# Guess: COW_REST (57.38% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f028735.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f029524.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f027042.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f024109.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f017104.mp4...
# Guess: COW_REST (55.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f023282.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f008193.mp4...
# Guess: COW_EAT (52.10% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0000_f022537.mp4...
# Guess: COW_REST (57.56% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f026665.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f024960.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0001_f002505.mp4...
# Guess: COW_REST (51.09% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f016368.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 47.74% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0000_f020192.mp4...
# Guess: COW_REST (56.09% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f023708.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f021255.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f027900.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f004291.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 37.63% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0000_f025815.mp4...
# Guess: COW_REST (57.40% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f033258.mp4...
# Guess: COW_WALK_STAND (57.53% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0000_f020915.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f012808.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 42.00% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0000_f021667.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f032612.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0000_f003099.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 46.43% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f017894.mp4...
# Guess: COW_REST (57.11% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f013336.mp4...
# Guess: COW_WALK_STAND (56.97% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f023495.mp4...
# Guess: COW_WALK_STAND (57.57% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f017520.mp4...
# Guess: COW_REST (57.30% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f030923.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 45.46% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f031326.mp4...
# Guess: COW_WALK_STAND (57.55% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f022328.mp4...
# Guess: COW_WALK_STAND (57.50% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f018762.mp4...
# Guess: COW_WALK_STAND (55.99% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f026908.mp4...
# Guess: COW_WALK_STAND (57.54% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f011810.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 48.70% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f029277.mp4...
# Guess: COW_REST (53.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f019629.mp4...
# Guess: COW_WALK_STAND (50.34% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f028915.mp4...
# Guess: COW_WALK_STAND (54.93% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f023115.mp4...
# Guess: COW_WALK_STAND (56.96% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f026205.mp4...
# Guess: COW_WALK_STAND (57.45% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f023887.mp4...
# Guess: COW_WALK_STAND (57.45% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f025044.mp4...
# Guess: COW_WALK_STAND (57.32% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f028096.mp4...
# Guess: COW_WALK_STAND (57.58% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f010619.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f018327.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f024291.mp4...
# Guess: COW_WALK_STAND (57.41% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f016804.mp4...
# Guess: COW_REST (51.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f028477.mp4...
# Guess: COW_REST (55.10% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f032898.mp4...
# Guess: COW_WALK_STAND (57.24% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f031705.mp4...
# Guess: COW_WALK_STAND (57.15% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f015620.mp4...
# Guess: COW_REST (52.69% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f030517.mp4...
# Guess: COW_REST (54.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f030080.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 45.86% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f032113.mp4...
# Guess: COW_WALK_STAND (50.86% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f025395.mp4...
# Guess: COW_WALK_STAND (56.13% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f019188.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 38.95% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f029670.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 42.69% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f025819.mp4...
# Guess: COW_WALK_STAND (57.16% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f026550.mp4...
# Guess: COW_WALK_STAND (57.31% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f024646.mp4...
# Guess: COW_WALK_STAND (56.08% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f027302.mp4...
# Guess: COW_WALK_STAND (57.50% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f006558.mp4...
# Guess: COW_REST (57.06% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f004623.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f002227.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f006949.mp4...
# Guess: COW_REST (57.21% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f014860.mp4...
# Guess: COW_REST (52.08% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f005390.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f016415.mp4...
# Guess: COW_REST (50.68% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f000251.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f007347.mp4...
# Guess: COW_REST (56.17% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f012575.mp4...
# Guess: COW_WALK_STAND (56.91% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f006138.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f000638.mp4...
# Guess: COW_REST (57.43% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f009420.mp4...
# Guess: COW_REST (57.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f020429.mp4...
# Guess: COW_WALK_STAND (57.59% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f004198.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f003789.mp4...
# Guess: COW_REST (57.20% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f011402.mp4...
# Guess: COW_REST (55.08% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f015227.mp4...
# Guess: COW_REST (53.80% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f003396.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f008155.mp4...
# Guess: COW_REST (56.34% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f010966.mp4...
# Guess: COW_REST (54.88% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f020034.mp4...
# Guess: COW_WALK_STAND (57.51% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f014475.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 41.55% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f028322.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 48.60% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0004_f022674.mp4...
# Guess: COW_WALK_STAND (55.95% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f012950.mp4...
# Guess: COW_REST (51.83% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f005001.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f008594.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f002996.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f009808.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f015996.mp4...
# Guess: COW_REST (53.19% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f002609.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f005767.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f009017.mp4...
# Guess: COW_REST (57.30% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f010241.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f033189.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0004_f007804.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f001484.mp4...
# Guess: COW_REST (57.48% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f001853.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f017161.mp4...
# Guess: COW_WALK_STAND (57.07% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0004_f014090.mp4...
# Guess: COW_REST (56.70% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f001039.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0004_f012196.mp4...
# Guess: COW_WALK_STAND (53.50% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0003_f032355.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0004_f013735.mp4...
# Guess: COW_WALK_STAND (52.06% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0003_f013313.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f004412.mp4...
# Guess: COW_REST (57.14% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f016529.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0002_f031572.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f012545.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f026705.mp4...
# Guess: COW_EAT (57.56% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f022059.mp4...
# Guess: COW_EAT (57.36% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f005939.mp4...
# Guess: COW_REST (56.91% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f011769.mp4...
# Guess: COW_EAT (57.40% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f014850.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f024381.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 48.10% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f014489.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f005173.mp4...
# Guess: COW_REST (56.70% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f017318.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f022460.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f008242.mp4...
# Guess: COW_EAT (51.91% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f013657.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f020091.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f022831.mp4...
# Guess: COW_EAT (57.56% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f019707.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f021696.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 49.46% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f015701.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f018906.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f023635.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f018114.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f020502.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f016926.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f025887.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 41.71% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f016121.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f017712.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f018537.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f021322.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f023241.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f004772.mp4...
# Guess: COW_REST (56.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f020923.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f014046.mp4...
# Guess: COW_EAT (56.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f012149.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0002_f031174.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 41.11% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f008630.mp4...
# Guess: COW_EAT (57.47% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f031960.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f019309.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0003_f026290.mp4...
# Guess: COW_REST (53.99% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0002_f019276.mp4...
# Guess: COW_WALK_STAND (54.30% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0003_f000716.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 49.97% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f003205.mp4...
# Guess: COW_REST (56.19% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0002_f013217.mp4...
# Guess: COW_WALK_STAND (57.42% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0002_f019646.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 49.40% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0003_f006322.mp4...
# Guess: COW_REST (57.27% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0002_f026409.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0002_f027599.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0002_f028030.mp4...
# Guess: COW_WALK_STAND (57.07% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0002_f027234.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr16_t0002_f022322.mp4...
# Guess: COW_WALK_STAND (51.19% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0002_f021894.mp4...
# Guess: COW_WALK_STAND (50.53% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0002_f015206.mp4...
# Guess: COW_REST (50.36% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f001163.mp4...
# Guess: COW_REST (56.96% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f003992.mp4...
# Guess: COW_REST (57.32% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0002_f025553.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 44.60% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr16_t0002_f016376.mp4...
# Guess: COW_REST (55.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0003_f003606.mp4...
# Guess: COW_REST (56.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr16_t0002_f033276.mp4...
# Guess: COW_WALK_STAND (56.65% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr16_t0002_f026824.mp4...
# ...
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0008_f018894.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 45.05% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0008_f020057.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0008_f023918.mp4...
# Guess: COW_EAT (57.53% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0008_f012587.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0008_f018143.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 47.12% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0008_f019629.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0008_f020786.mp4...
# Guess: COW_EAT (57.40% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0008_f012958.mp4...
# Guess: COW_REST (54.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0009_f001345.mp4...
# Guess: COW_WALK_STAND (57.54% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0008_f019245.mp4...
# Guess: COW_REST (52.03% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f032560.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0000_f004178.mp4...
# Guess: COW_REST (57.40% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0001_f002277.mp4...
# Guess: COW_WALK_STAND (55.53% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0000_f010658.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0001_f006689.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f000112.mp4...
# Guess: COW_REST (56.78% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f004970.mp4...
# Guess: COW_REST (57.39% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f016168.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0000_f025025.mp4...
# Guess: COW_WALK_STAND (57.33% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0001_f004683.mp4...
# Guess: COW_REST (55.78% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0001_f005457.mp4...
# Guess: COW_REST (57.10% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0001_f005822.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f007372.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0000_f004616.mp4...
# Guess: COW_REST (56.90% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f008953.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 43.37% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0001_f001425.mp4...
# Guess: COW_WALK_STAND (57.07% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0000_f003773.mp4...
# Guess: COW_REST (57.11% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f015715.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0001_f002686.mp4...
# Guess: COW_WALK_STAND (56.55% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0001_f001864.mp4...
# Guess: COW_WALK_STAND (57.60% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr18_t0000_f006957.mp4...
# Guess: COW_REST (54.70% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f006544.mp4...
# Guess: COW_REST (56.03% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f032909.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0000_f005372.mp4...
# Guess: COW_REST (57.18% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f001788.mp4...
# Guess: COW_REST (56.93% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f016520.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f018767.mp4...
# Guess: COW_REST (57.44% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f018023.mp4...
# Guess: COW_REST (54.29% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f014487.mp4...
# Guess: COW_REST (56.12% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f018408.mp4...
# Guess: COW_REST (57.34% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f030914.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f019587.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 49.26% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0009_f000841.mp4...
# Guess: COW_WALK_STAND (57.60% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0009_f010203.mp4...
# Guess: COW_REST (57.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f027087.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr18_t0000_f005786.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f009810.mp4...
# Guess: COW_REST (56.80% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f017664.mp4...
# Guess: COW_REST (57.13% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f012953.mp4...
# Guess: COW_REST (57.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f000896.mp4...
# Guess: COW_REST (56.93% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f019185.mp4...
# Guess: COW_REST (57.18% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f016100.mp4...
# Guess: COW_REST (57.37% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f000499.mp4...
# Guess: COW_REST (57.36% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0001_f005081.mp4...
# Guess: COW_REST (56.68% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f002975.mp4...
# Guess: COW_REST (56.81% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f001332.mp4...
# Guess: COW_REST (55.09% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f002169.mp4...
# Guess: COW_REST (57.28% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f021258.mp4...
# Guess: COW_REST (56.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f015701.mp4...
# Guess: COW_REST (54.38% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f022219.mp4...
# Guess: COW_EAT (57.57% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f026720.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 48.56% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr18_t0000_f002574.mp4...
# Guess: COW_REST (56.61% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f015277.mp4...
# Guess: COW_REST (57.39% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr18_t0000_f003406.mp4...
# Guess: COW_REST (57.43% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f030525.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f001609.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 39.23% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0009_f002484.mp4...
# Guess: COW_REST (57.59% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f006633.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f007408.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f008609.mp4...
# Guess: COW_REST (57.25% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f026133.mp4...
# Guess: COW_EAT (57.55% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f003289.mp4...
# Guess: COW_REST (57.58% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f008202.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f012541.mp4...
# Guess: COW_REST (57.10% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f009468.mp4...
# Guess: COW_REST (57.23% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f025785.mp4...
# Guess: COW_REST (56.90% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f010968.mp4...
# Guess: COW_REST (57.22% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f005797.mp4...
# Guess: COW_REST (57.49% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f030098.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0008_f030827.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f017302.mp4...
# Guess: COW_REST (57.52% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f003673.mp4...
# Guess: COW_REST (57.31% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f006228.mp4...
# Guess: COW_REST (57.51% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f004096.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f013363.mp4...
# Guess: COW_REST (57.42% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f030449.mp4...
# Guess: COW_EAT (57.35% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f013742.mp4...
# Guess: COW_REST (56.47% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f014140.mp4...
# Guess: COW_REST (57.20% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f002891.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f017113.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0008_f032439.mp4...
# Guess: COW_WALK_STAND (57.46% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0009_f009072.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f016919.mp4...
# Guess: COW_REST (57.41% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f026517.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f011751.mp4...
# Guess: COW_REST (57.33% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f000005.mp4...
# Guess: COW_WALK_STAND (57.55% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0009_f007048.mp4...
# Guess: COW_REST (57.34% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f000429.mp4...
# Guess: COW_WALK_STAND (57.51% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0008_f016712.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f027249.mp4...
# Guess: COW_REST (57.14% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f032043.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 48.28% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0009_f007803.mp4...
# Guess: COW_REST (57.41% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f004539.mp4...
# Guess: COW_REST (57.50% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f010037.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f001200.mp4...
# Guess: COW_WALK_STAND (57.57% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0008_f031631.mp4...
# Guess: COW_REST (50.11% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0009_f004990.mp4...
# Guess: COW_REST (57.56% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f012737.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 37.69% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0008_f015885.mp4...
# Guess: COW_EAT (57.59% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f010561.mp4...
# Guess: COW_REST (57.18% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f012324.mp4...
# Guess: COW_EAT (57.58% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0008_f014711.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_EAT, only 48.88% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0009_f002078.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_WALK_STAND, only 44.59% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0008_f032834.mp4...
# Guess: COW_WALK_STAND (57.50% sure)
# -> Safely copied into Predicted_cow_walk_stand!
#
# Watching: apr17_t0009_f011363.mp4...
# Guess: COW_REST (57.45% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f024806.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f020313.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f025206.mp4...
# Guess: COW_EAT (52.79% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f012138.mp4...
# Guess: COW_REST (57.04% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0008_f003124.mp4...
# Guess: COW_EAT (57.41% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f014355.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f005511.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f021911.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f026848.mp4...
# Guess: MISCELLANEOUS (Unsure about COW_REST, only 42.10% sure)
# -> Safely copied into Predicted_Miscellaneous!
#
# Watching: apr17_t0007_f005113.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0009_f005384.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f015548.mp4...
# Guess: COW_EAT (57.60% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0008_f002717.mp4...
# Guess: COW_EAT (57.39% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f002736.mp4...
# Guess: COW_REST (57.57% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f031861.mp4...
# Guess: COW_REST (57.53% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f020702.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f027807.mp4...
# Guess: COW_REST (57.55% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f025674.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f033094.mp4...
# Guess: COW_REST (57.39% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f021082.mp4...
# Guess: COW_EAT (57.54% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0007_f003926.mp4...
# Guess: COW_EAT (53.18% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f023013.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# Watching: apr17_t0006_f025476.mp4...
# Guess: COW_REST (57.43% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0006_f025101.mp4...
# Guess: COW_REST (57.54% sure)
# -> Safely copied into Predicted_cow_rest!
#
# Watching: apr17_t0007_f021492.mp4...
# Guess: COW_EAT (57.61% sure)
# -> Safely copied into Predicted_cow_eat!
#
# --- ALL DONE! CHECK YOUR RESULT FOLDERS! ---
